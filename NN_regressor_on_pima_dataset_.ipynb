# %% [markdown]
# <a href="https://colab.research.google.com/github/AryanilAD/Corporate-Training-Mini_Projects/blob/main/NN_regressor_on_pima_dataset_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV

# %%
df=pd.read_csv('/content/diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Split the dataset into features and target
X = df.drop('Outcome', axis=1)
y = df['Outcome']

# %%
# Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Build a more complex neural network model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(1)  # Output layer with linear activation for regression
])

# %%
# Compile the model
model.compile(optimizer='adam', loss='mse')

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/100
# 14/14 [==============================] - 1s 11ms/step - loss: 23.9346 - val_loss: 9.9568
# Epoch 2/100
# 14/14 [==============================] - 0s 5ms/step - loss: 4.4396 - val_loss: 2.1344
# Epoch 3/100
# 14/14 [==============================] - 0s 4ms/step - loss: 1.3600 - val_loss: 1.5882
# Epoch 4/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.7194 - val_loss: 0.5393
# Epoch 5/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.7264 - val_loss: 0.4636
# Epoch 6/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.8853 - val_loss: 1.9811
# Epoch 7/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6971 - val_loss: 0.7100
# Epoch 8/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4005 - val_loss: 0.6521
# Epoch 9/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3279 - val_loss: 0.6605
# Epoch 10/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3150 - val_loss: 0.9298
# Epoch 11/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3172 - val_loss: 0.4411
# Epoch 12/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2712 - val_loss: 0.3470
# Epoch 13/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2781 - val_loss: 0.3097
# Epoch 14/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2975 - val_loss: 0.4497
# Epoch 15/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2698 - val_loss: 0.5131
# Epoch 16/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3115 - val_loss: 0.4135
# Epoch 17/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2364 - val_loss: 0.4707
# Epoch 18/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2279 - val_loss: 0.5593
# Epoch 19/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2387 - val_loss: 0.4222
# Epoch 20/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2678 - val_loss: 0.4638
# Epoch 21/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2346 - val_loss: 0.3337
# Epoch 22/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2123 - val_loss: 0.3819
# Epoch 23/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2124 - val_loss: 0.4169
# Epoch 24/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2264 - val_loss: 0.3202
# Epoch 25/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2094 - val_loss: 0.5138
# Epoch 26/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2599 - val_loss: 0.3520
# Epoch 27/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3137 - val_loss: 0.7748
# Epoch 28/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2516 - val_loss: 0.7248
# Epoch 29/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4746 - val_loss: 0.2461
# Epoch 30/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3648 - val_loss: 0.7684
# Epoch 31/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5750 - val_loss: 0.4988
# Epoch 32/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3102 - val_loss: 0.3388
# Epoch 33/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2514 - val_loss: 0.3256
# Epoch 34/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3401 - val_loss: 0.3885
# Epoch 35/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3904 - val_loss: 0.2948
# Epoch 36/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1971 - val_loss: 0.2456
# Epoch 37/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3914 - val_loss: 0.7026
# Epoch 38/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3139 - val_loss: 0.6980
# Epoch 39/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3902 - val_loss: 0.5554
# Epoch 40/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2590 - val_loss: 0.3159
# Epoch 41/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2580 - val_loss: 0.4036
# Epoch 42/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2177 - val_loss: 0.5246
# Epoch 43/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2716 - val_loss: 0.5625
# Epoch 44/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3209 - val_loss: 0.4612
# Epoch 45/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2627 - val_loss: 0.4431
# Epoch 46/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4754 - val_loss: 0.5352
# Epoch 47/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3878 - val_loss: 0.3677
# Epoch 48/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2909 - val_loss: 0.4178
# Epoch 49/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2807 - val_loss: 0.4299
# Epoch 50/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3172 - val_loss: 0.2271
# Epoch 51/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2120 - val_loss: 0.4621
# Epoch 52/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3238 - val_loss: 0.4784
# Epoch 53/100
# 14/14 [==============================] - 0s 4ms/step - loss: 1.1655 - val_loss: 0.6731
# Epoch 54/100
# 14/14 [==============================] - 0s 3ms/step - loss: 1.3224 - val_loss: 0.4211
# Epoch 55/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3461 - val_loss: 0.3390
# Epoch 56/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2410 - val_loss: 0.3161
# Epoch 57/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2099 - val_loss: 0.3754
# Epoch 58/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1984 - val_loss: 0.5465
# Epoch 59/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2570 - val_loss: 0.3156
# Epoch 60/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1945 - val_loss: 0.4546
# Epoch 61/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2117 - val_loss: 0.2862
# Epoch 62/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2476 - val_loss: 0.5122
# Epoch 63/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3336 - val_loss: 0.4130
# Epoch 64/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4043 - val_loss: 0.8093
# Epoch 65/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.7045 - val_loss: 1.2811
# Epoch 66/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.5985 - val_loss: 0.9677
# Epoch 67/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3377 - val_loss: 0.4933
# Epoch 68/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1785 - val_loss: 0.2526
# Epoch 69/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1773 - val_loss: 0.2797
# Epoch 70/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2351 - val_loss: 0.2781
# Epoch 71/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2227 - val_loss: 0.4727
# Epoch 72/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2459 - val_loss: 0.3565
# Epoch 73/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3164 - val_loss: 0.6621
# Epoch 74/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3653 - val_loss: 0.3323
# Epoch 75/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2635 - val_loss: 0.5496
# Epoch 76/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1990 - val_loss: 0.2910
# Epoch 77/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2174 - val_loss: 0.3546
# Epoch 78/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1851 - val_loss: 0.4632
# Epoch 79/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2170 - val_loss: 0.2890
# Epoch 80/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2363 - val_loss: 0.4577
# Epoch 81/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3927 - val_loss: 0.7728
# Epoch 82/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5526 - val_loss: 0.6902
# Epoch 83/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4003 - val_loss: 0.3861
# Epoch 84/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2795 - val_loss: 0.6273
# Epoch 85/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2997 - val_loss: 0.2874
# Epoch 86/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2608 - val_loss: 0.3029
# Epoch 87/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1814 - val_loss: 0.2891
# Epoch 88/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1741 - val_loss: 0.5500
# Epoch 89/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3373 - val_loss: 0.3236
# Epoch 90/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3279 - val_loss: 0.6756
# Epoch 91/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4197 - val_loss: 0.3134
# Epoch 92/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3358 - val_loss: 0.2445
# Epoch 93/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2266 - val_loss: 0.2909
# Epoch 94/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2202 - val_loss: 0.3335
# Epoch 95/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2161 - val_loss: 0.3593
# Epoch 96/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1764 - val_loss: 0.2988
# Epoch 97/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3422 - val_loss: 0.5670
# Epoch 98/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3328 - val_loss: 0.4424
# Epoch 99/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2184 - val_loss: 0.2546
# Epoch 100/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1534 - val_loss: 0.2151

# %%
# Predict on the test set
y_pred = model.predict(X_test)
# Out:
# 8/8 [==============================] - 0s 1ms/step

# %%
# Calculate mean squared error (MSE)
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error (MSE): {mse}')
# Out:
# Mean Squared Error (MSE): 0.2598048623503886

# %%
# Evaluate the model
loss = model.evaluate(X_train, y_train, verbose=0)
print(f'Train Loss: {loss}')

loss = model.evaluate(X_test, y_test, verbose=0)
print(f'Test Loss: {loss}')
# Out:
# Train Loss: 0.16630497574806213
# Test Loss: 0.2598048746585846
